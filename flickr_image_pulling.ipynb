# %%
from flickrapi import FlickrAPI

# %%
KEY = ''
SECRET = ''

# %%
flickr = FlickrAPI(KEY, SECRET, format='parsed-json')

# %%
extras='url_sq,url_t,url_s,url_q,url_m,url_n,url_z,url_c,url_l,url_o'

# %%
como = flickr.photos.search(text='como', per_page=5, extras=extras)

# %%
photos = como['photos']

# %%
from pprint import pprint

# %%
pprint(photos)
# Out:
# {'page': 1,
#  'pages': 86460,
#  'perpage': 5,
#  'photo': [{'farm': 66,
#             'height_c': 800,
#             'height_l': 1024,
#             'height_m': 500,
#             'height_n': 320,
#             'height_o': 2000,
#             'height_q': 150,
#             'height_s': 240,
#             'height_sq': 75,
#             'height_t': 100,
#             'height_z': 640,
#             'id': '49668825322',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186649010@N08',
#             'secret': '30536aa779',
#             'server': '65535',
#             'title': 'Handmade Bracelets',
#             'url_c': 'https://live.staticflickr.com/65535/49668825322_30536aa779_c.jpg',
#             'url_l': 'https://live.staticflickr.com/65535/49668825322_30536aa779_b.jpg',
#             'url_m': 'https://live.staticflickr.com/65535/49668825322_30536aa779.jpg',
#             'url_n': 'https://live.staticflickr.com/65535/49668825322_30536aa779_n.jpg',
#             'url_o': 'https://live.staticflickr.com/65535/49668825322_1151e96314_o.jpg',
#             'url_q': 'https://live.staticflickr.com/65535/49668825322_30536aa779_q.jpg',
#             'url_s': 'https://live.staticflickr.com/65535/49668825322_30536aa779_m.jpg',
#             'url_sq': 'https://live.staticflickr.com/65535/49668825322_30536aa779_s.jpg',
#             'url_t': 'https://live.staticflickr.com/65535/49668825322_30536aa779_t.jpg',
#             'url_z': 'https://live.staticflickr.com/65535/49668825322_30536aa779_z.jpg',
#             'width_c': 566,
#             'width_l': 724,
#             'width_m': 354,
#             'width_n': 226,
#             'width_o': 1414,
#             'width_q': 150,
#             'width_s': 170,
#             'width_sq': 75,
#             'width_t': 71,
#             'width_z': 452},
#            {'farm': 66,
#             'height_n': 170,
#             'height_o': 170,
#             'height_q': 150,
#             'height_s': 137,
#             'height_sq': 75,
#             'height_t': 57,
#             'id': '49668459216',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186512285@N06',
#             'secret': '8b3f9f52c5',
#             'server': '65535',
#             'title': 'como rastrear celular (how to track cell phone)',
#             'url_n': 'https://live.staticflickr.com/65535/49668459216_8b3f9f52c5_n.jpg',
#             'url_o': 'https://live.staticflickr.com/65535/49668459216_570c023853_o.jpg',
#             'url_q': 'https://live.staticflickr.com/65535/49668459216_8b3f9f52c5_q.jpg',
#             'url_s': 'https://live.staticflickr.com/65535/49668459216_8b3f9f52c5_m.jpg',
#             'url_sq': 'https://live.staticflickr.com/65535/49668459216_8b3f9f52c5_s.jpg',
#             'url_t': 'https://live.staticflickr.com/65535/49668459216_8b3f9f52c5_t.jpg',
#             'width_n': 297,
#             'width_o': 297,
#             'width_q': 150,
#             'width_s': 240,
#             'width_sq': 75,
#             'width_t': 100},
#            {'farm': 66,
#             'height_c': 533,
#             'height_l': 683,
#             'height_m': 333,
#             'height_n': 213,
#             'height_q': 150,
#             'height_s': 160,
#             'height_sq': 75,
#             'height_t': 67,
#             'height_z': 427,
#             'id': '49668570867',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '93187349@N07',
#             'secret': 'b66b689d2b',
#             'server': '65535',
#             'title': 'Sunset Strip',
#             'url_c': 'https://live.staticflickr.com/65535/49668570867_b66b689d2b_c.jpg',
#             'url_l': 'https://live.staticflickr.com/65535/49668570867_b66b689d2b_b.jpg',
#             'url_m': 'https://live.staticflickr.com/65535/49668570867_b66b689d2b.jpg',
#             'url_n': 'https://live.staticflickr.com/65535/49668570867_b66b689d2b_n.jpg',
#             'url_q': 'https://live.staticflickr.com/65535/49668570867_b66b689d2b_q.jpg',
#             'url_s': 'https://live.staticflickr.com/65535/49668570867_b66b689d2b_m.jpg',
#             'url_sq': 'https://live.staticflickr.com/65535/49668570867_b66b689d2b_s.jpg',
#             'url_t': 'https://live.staticflickr.com/65535/49668570867_b66b689d2b_t.jpg',
#             'url_z': 'https://live.staticflickr.com/65535/49668570867_b66b689d2b_z.jpg',
#             'width_c': 800,
#             'width_l': 1024,
#             'width_m': 500,
#             'width_n': 320,
#             'width_q': 150,
#             'width_s': 240,
#             'width_sq': 75,
#             'width_t': 100,
#             'width_z': 640},
#            {'farm': 66,
#             'height_c': 533,
#             'height_l': 683,
#             'height_m': 333,
#             'height_n': 213,
#             'height_q': 150,
#             'height_s': 160,
#             'height_sq': 75,
#             'height_t': 67,
#             'height_z': 427,
#             'id': '49668026246',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '107344853@N05',
#             'secret': 'b5c91f3145',
#             'server': '65535',
#             'title': '...',
#             'url_c': 'https://live.staticflickr.com/65535/49668026246_b5c91f3145_c.jpg',
#             'url_l': 'https://live.staticflickr.com/65535/49668026246_b5c91f3145_b.jpg',
#             'url_m': 'https://live.staticflickr.com/65535/49668026246_b5c91f3145.jpg',
#             'url_n': 'https://live.staticflickr.com/65535/49668026246_b5c91f3145_n.jpg',
#             'url_q': 'https://live.staticflickr.com/65535/49668026246_b5c91f3145_q.jpg',
#             'url_s': 'https://live.staticflickr.com/65535/49668026246_b5c91f3145_m.jpg',
#             'url_sq': 'https://live.staticflickr.com/65535/49668026246_b5c91f3145_s.jpg',
#             'url_t': 'https://live.staticflickr.com/65535/49668026246_b5c91f3145_t.jpg',
#             'url_z': 'https://live.staticflickr.com/65535/49668026246_b5c91f3145_z.jpg',
#             'width_c': 800,
#             'width_l': 1024,
#             'width_m': 500,
#             'width_n': 320,
#             'width_q': 150,
#             'width_s': 240,
#             'width_sq': 75,
#             'width_t': 100,
#             'width_z': 640},
#            {'farm': 66,
#             'height_c': 800,
#             'height_l': 1024,
#             'height_m': 500,
#             'height_n': 320,
#             'height_o': 1200,
#             'height_q': 150,
#             'height_s': 240,
#             'height_sq': 75,
#             'height_t': 100,
#             'height_z': 640,
#             'id': '49668040931',
#             'isfamily': 0,
#             'isfriend': 0,
#             'ispublic': 1,
#             'owner': '186302614@N08',
#             'secret': '6255faec2c',
#             'server': '65535',
#             'title': '¿Cómo puedes ser un creyente sincero?',
#             'url_c': 'https://live.staticflickr.com/65535/49668040931_6255faec2c_c.jpg',
#             'url_l': 'https://live.staticflickr.com/65535/49668040931_6255faec2c_b.jpg',
#             'url_m': 'https://live.staticflickr.com/65535/49668040931_6255faec2c.jpg',
#             'url_n': 'https://live.staticflickr.com/65535/49668040931_6255faec2c_n.jpg',
#             'url_o': 'https://live.staticflickr.com/65535/49668040931_4582b8b71c_o.jpg',
#             'url_q': 'https://live.staticflickr.com/65535/49668040931_6255faec2c_q.jpg',
#             'url_s': 'https://live.staticflickr.com/65535/49668040931_6255faec2c_m.jpg',
#             'url_sq': 'https://live.staticflickr.com/65535/49668040931_6255faec2c_s.jpg',
#             'url_t': 'https://live.staticflickr.com/65535/49668040931_6255faec2c_t.jpg',
#             'url_z': 'https://live.staticflickr.com/65535/49668040931_6255faec2c_z.jpg',
#             'width_c': 450,
#             'width_l': 576,
#             'width_m': 281,
#             'width_n': 180,
#             'width_o': 675,
#             'width_q': 150,
#             'width_s': 135,
#             'width_sq': 75,
#             'width_t': 56,
#             'width_z': 360}],
#  'total': '432300'}

# %%
import numpy as np
import urllib
import cv2

# %%
def url_to_image(url):
    resp = urllib.request.urlopen(url)
    image = np.asarray(bytearray(resp.read()), dtype='uint8')
    image = cv2.imdecode(image, cv2.IMREAD_COLOR)
    
    return image
